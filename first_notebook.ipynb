# %% [markdown]
# <a href="https://colab.research.google.com/github/DJKeekarikattu/DJKeekarikattu/blob/main/first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# This is my first notebook.

# %%
a=5
b=8
sum=a+b
print("Sum is :",sum)
# Out:
# Sum is : 13

# %%
x = 1
y = 35656222554887711
z = -3255522.0

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(1,5,1000)
y=np.exp(-0.263*x)+3*np.sin(5*x)
plt.plot(x,y)
plt.show()
